# %% [markdown]
# ### Final Code for Sex differences project

# %% [markdown]
# ### 1. Prep data set

# %%
# %matplotlib inline
import glob
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split 

import pandas as pd
import seaborn as sns; sns.set()
import os
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline 
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from pathlib import Path


from nilearn import plotting,image 
from sklearn.metrics import confusion_matrix

# %%
#import data set
df = pd.read_csv("/home/xlajoie/Desktop/unrestricted_original.csv")

# %%
# Filter left-handers (>=50 handedness) 
df = df[df["Handedness"] >= 50].reset_index()

# %%
# transform M and F with 0 and 1 

df.rename(columns={"Subject": "subject_label"}, inplace=True)
df["Gender"] = df["Gender"].replace({"M": 0, "F": 1})
df
# Out:
#      index  subject_label Release Acquisition  Gender  Age_in_Yrs  \
# 0        0         100206    S900         Q11       0          27
# 1        1         100610    S900         Q08       0          27
# 2        2         101006    S500         Q06       1          35
# 3        4         102008    S500         Q06       0          24
# 4        7         102513    S900         Q10       0          30
# ..     ...            ...     ...         ...     ...         ...
# 559    662         990366    S900         Q10       0          22
# 560    663         991267    S500         Q06       0          30
# 561    664         992673    S900         Q12       1          33
# 562    665         993675    S900         Q09       1          29
# 563    666         996782    S900         Q08       1          28
#
#                      Race            Ethnicity  Handedness  Education  ...  \
# 0                   White  Not Hispanic/Latino          65       16.0  ...
# 1                   White  Not Hispanic/Latino          85       16.0  ...
# 2    Black or African Am.  Not Hispanic/Latino          90       12.0  ...
# 3                   White      Hispanic/Latino          80       12.0  ...
# 4                   White  Not Hispanic/Latino          50       14.0  ...
# ..                    ...                  ...         ...        ...  ...
# 559                 White  Not Hispanic/Latino          95       15.0  ...
# 560                 White  Not Hispanic/Latino          75       14.0  ...
# 561                 White  Not Hispanic/Latino          70       14.0  ...
# 562                 White  Not Hispanic/Latino          85       16.0  ...
# 563                 White  Not Hispanic/Latino         100       16.0  ...
#
#      Noise_Comp  Odor_Unadj  Odor_AgeAdj  PainIntens_RawScore  \
# 0           6.0      108.79        97.19                  1.0
# 1           2.0      122.25       110.45                  0.0
# 2           6.0      122.25       111.41                  0.0
# 3           6.0      122.25       110.45                  0.0
# 4           5.2      108.79        98.04                  2.0
# ..          ...         ...          ...                  ...
# 559         4.4      108.79        97.19                  1.0
# 560         2.8      122.25       111.41                  1.0
# 561         3.6      122.25       111.41                  1.0
# 562         0.4      122.25       110.45                  0.0
# 563         6.0      108.79        97.19                  0.0
#
#      PainInterf_Tscore  Taste_Unadj  Taste_AgeAdj  Mars_Log_Score  Mars_Errs  \
# 0                 49.7        72.63         72.03            1.84        0.0
# 1                 38.6        84.84         85.31            1.92        1.0
# 2                 38.6       123.80        123.31            1.80        0.0
# 3                 50.1        67.48         65.31            1.80        0.0
# 4                 54.3        84.07         82.37            1.92        0.0
# ..                 ...          ...           ...             ...        ...
# 559               52.6        93.82         92.63            1.80        0.0
# 560               46.6        83.23         81.55            1.84        0.0
# 561               38.6       101.63         99.26            1.80        0.0
# 562               38.6        84.07         84.25            1.80        1.0
# 563               38.6        75.43         73.72            1.84        0.0
#
#      Mars_Final
# 0          1.84
# 1          1.88
# 2          1.80
# 3          1.80
# 4          1.92
# ..          ...
# 559        1.80
# 560        1.84
# 561        1.80
# 562        1.76
# 563        1.84
#
# [564 rows x 388 columns]

# %%
print(df['Gender'].value_counts()[0])
print(df['Gender'].value_counts()[1])
# Out:
# 263
# 301

# %%
#save new csv with modifications as "final hcp database"
df.to_csv("/home/xlajoie/Desktop/Final_HCP_database.csv")

# %%
# load dataset containing sex and participant id
df = pd.read_csv("/home/xlajoie/Desktop/Final_HCP_database.csv")

# %%
df["Gender"]  # should have the whole list
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 559    0
# 560    0
# 561    1
# 562    1
# 563    1
# Name: Gender, Length: 564, dtype: int64

# %%
from nilearn import datasets
from nilearn.maskers import NiftiLabelsMasker 

atlas_aal = datasets.fetch_atlas_aal()
masker = NiftiLabelsMasker(atlas_aal.maps) #si masker niftimasker MNI = devient tout les voxels 

def img4d2vector(img_path, masker):
    img_masked = masker.fit_transform(img_path)  #fait une moyenne par label 
    return img_masked.flatten()  #devient 1 vecteur

def vector2img4d(vector, masker):
    data_2d = vector.reshape(8, -1)
    return masker.inverse_transform(data_2d)   #remettre dans espace MNI that we can plot with nilearn

# %%
print(len(atlas_aal.labels))
# Out:
# 116

# %%
img_tpl = "/data/brambati/dataset/HCP/derivatives/seed-to-voxel-nilearn/results/sub-{0}/sub-{0}_voxelcorrelations.nii.gz"  # à changer

x_correl = []
nb_subjects = 200
subject_label = df["subject_label"][:nb_subjects]

for sub in tqdm(subject_label):
    img_path = str(Path(img_tpl.format(sub)))  # format = remplace entre accolades par # sujet
    x_correl.append(img4d2vector(img_path, masker))

x_correl = np.array(x_correl)
x_correl.shape  # autant de lignes que de sujets, autant de colones (nb region atlas x 8 (seeds))
# Out:
#   4%|▍         | 8/200 [00:08<03:31,  1.10s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e391b3cb57d9> in <module>
#       7 for sub in tqdm(subject_label):
#       8     img_path = str(Path(img_tpl.format(sub)))  # format = remplace entre accolades par # sujet
# ----> 9     x_correl.append(img4d2vector(img_path, masker))
#      10
#      11 x_correl = np.array(x_correl)
#
# <ipython-input-9-82cffa08f106> in img4d2vector(img_path, masker)
#       6
#       7 def img4d2vector(img_path, masker):
# ----> 8     img_masked = masker.fit_transform(img_path)  #fait une moyenne par label
#       9     return img_masked.flatten()  #devient 1 vecteur
#      10
#
# /data/brambati/local/venvs/lingualab_server/lib/python3.6/site-packages/nilearn/maskers/nifti_labels_masker.py in fit_transform(self, imgs, confounds, sample_mask)
#     487         """
#     488         return self.fit().transform(imgs, confounds=confounds,
# --> 489                                     sample_mask=sample_mask)
#     490
#     491     def _check_fitted(self):
#
# /data/brambati/local/venvs/lingualab_server/lib/python3.6/site-packages/nilearn/maskers/base_masker.py in transform(self, imgs, confounds, sample_mask)
#     233             return self.transform_single_imgs(imgs,
#     234                                               confounds=confounds,
# --> 235                                               sample_mask=sample_mask)
#     236
#     237         # Compute high variance confounds if requested
#
# /data/brambati/local/venvs/lingualab_server/lib/python3.6/site-packages/nilearn/maskers/nifti_labels_masker.py in transform_single_imgs(self, imgs, confounds, sample_mask)
#     546
#     547         if self.resampling_target == "data":
# --> 548             imgs_ = _utils.check_niimg(imgs, atleast_4d=True)
#     549             if not _utils.niimg_conversions._check_same_fov(
#     550                 imgs_,
#
# /data/brambati/local/venvs/lingualab_server/lib/python3.6/site-packages/nilearn/_utils/niimg_conversions.py in check_niimg(niimg, ensure_ndim, atleast_4d, dtype, return_iterator, wildcards)
#     284
#     285     # Otherwise, it should be a filename or a SpatialImage, we load it
# --> 286     niimg = load_niimg(niimg, dtype=dtype)
#     287
#     288     if ensure_ndim == 3 and len(niimg.shape) == 4 and niimg.shape[3] == 1:
#
# /data/brambati/local/venvs/lingualab_server/lib/python3.6/site-packages/nilearn/_utils/niimg.py in load_niimg(niimg, dtype)
#     135                         + _repr_niimgs(niimg, shorten=True))
#     136
# --> 137     dtype = _get_target_dtype(_get_data(niimg).dtype, dtype)
#     138
#     139     if dtype is not None:
#
# /data/brambati/local/venvs/lingualab_server/lib/python3.6/site-packages/nilearn/_utils/niimg.py in _get_data(img)
#      24     if img._data_cache is not None:
#      25         return img._data_cache
# ---> 26     data = np.asanyarray(img._dataobj)
#      27     img._data_cache = data
#      28     return data
#
# /data/brambati/local/venvs/lingualab_server/lib/python3.6/site-packages/numpy/core/_asarray.py in asanyarray(a, dtype, order)
#     134
#     135     """
# --> 136     return array(a, dtype, copy=False, order=order, subok=True)
#     137
#     138
#
# /data/brambati/local/venvs/lingualab_server/lib/python3.6/site-packages/nibabel/arrayproxy.py in __array__(self, dtype)
#     389             Scaled image data with type `dtype`.
#     390         """
# --> 391         arr = self._get_scaled(dtype=dtype, slicer=())
#     392         if dtype is not None:
#     393             arr = arr.astype(dtype, copy=False)
#
# /data/brambati/local/venvs/lingualab_server/lib/python3.6/site-packages/nibabel/arrayproxy.py in _get_scaled(self, dtype, slicer)
#     356             scl_inter = scl_inter.astype(use_dtype)
#     357         # Read array and upcast as necessary for big slopes, intercepts
# --> 358         scaled = apply_read_scaling(self._get_unscaled(slicer=slicer), scl_slope, scl_inter)
#     359         if dtype is not None:
#     360             scaled = scaled.astype(np.promote_types(scaled.dtype, dtype), copy=False)
#
# /data/brambati/local/venvs/lingualab_server/lib/python3.6/site-packages/nibabel/arrayproxy.py in _get_unscaled(self, slicer)
#     335                                        offset=self._offset,
#     336                                        order=self.order,
# --> 337                                        mmap=self._mmap)
#     338         with self._get_fileobj() as fileobj:
#     339             return fileslice(fileobj,
#
# /data/brambati/local/venvs/lingualab_server/lib/python3.6/site-packages/nibabel/volumeutils.py in array_from_file(shape, in_dtype, infile, offset, order, mmap)
#     520     if hasattr(infile, 'readinto'):
#     521         data_bytes = bytearray(n_bytes)
# --> 522         n_read = infile.readinto(data_bytes)
#     523         needs_copy = False
#     524     else:
#
# /usr/lib/python3.6/gzip.py in read(self, size)
#     274             import errno
#     275             raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 276         return self._buffer.read(size)
#     277
#     278     def read1(self, size=-1):
#
# /usr/lib/python3.6/_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# /usr/lib/python3.6/gzip.py in read(self, size)
#     483                                "end-of-stream marker was reached")
#     484
# --> 485         self._add_read_data( uncompress )
#     486         self._pos += len(uncompress)
#     487         return uncompress
#
# /usr/lib/python3.6/gzip.py in _add_read_data(self, data)
#     488
#     489     def _add_read_data(self, data):
# --> 490         self._crc = zlib.crc32(data, self._crc)
#     491         self._stream_size = self._stream_size + len(data)
#     492
#
# KeyboardInterrupt:

# %%
# prendre sex et le mettre dans une liste

y_sex = df["Gender"][:nb_subjects]  # maybe list(df["Gender"])

# %%
print(sum(y_sex), len(y_sex))  #double check
# Out:
# 105 200

# %% [markdown]
# #### 2. Classifier

# %%
# split the sample o training/test with a 80/20 % ratio 
# and stratify sex by class, also shuffle the data

X_train, X_test, y_train, y_test = train_test_split( 
                                                    x_correl,  # x 
                                                    y_sex,       # y 
                                                    test_size = 0.2, # 80%/20% split 
                                                    shuffle = True,  #shuffle dataset before splitting
                                                    stratify = y_sex,  # keep distribution of sex_class consistent between train and test sets
                                                    random_state = 123) #same shuffle each time 

print('train:', len(X_train),'test:', len(X_test))
# Out:
# train: 160 test: 40

# %%
score = []

model = LinearSVC()

#score = cross_val_score(model, X_train, y_train, cv=10)
score.append(cross_val_score(model, X_train, y_train, cv=10, n_jobs = 3).mean())

# %%
print(score)
# Out:
# [0.75]

# %%
model.fit(X_train,y_train) #fit the model/ train the model
y_pred = model.predict(X_test)

#calculate the model accuracy
acc = model.score(X_test, y_test)

#compute the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = conf_matrix.ravel()
df = pd.DataFrame(data=[[tn, fp],[fn,tp]], index= ["True", "False"], columns = ["Positive", "Negative"])
print(df.head())

# print results
print('accuracy (r2) =', acc)
# Out:
#        Positive  Negative
# True         16         3
# False         4        17
# accuracy (r2) = 0.825

# %%
coef = model.coef_[0]

plt.bar(range(model.coef_.shape[-1]),model.coef_[0])
plt.title('feature importances')
plt.xlabel('feature')
plt.ylabel('weight')
# Out:
# Text(0, 0.5, 'weight')

# %%
#coef_image = vector2img4d(np.abs(coef),masker) 
coef_image = vector2img4d(coef,masker) 

coef_image

# %%
for img in image.iter_img(coef_image):
    # img is now an in-memory 3D img
    plotting.plot_stat_map(img,
                           #threshold=0.05,
                           #display_mode="z", cut_coords=1,
                           #colorbar=False,
                          )

# %% [markdown]
# ### Essai avec PCA and best n components

# %% [markdown]
# Le x_correl est la meme que celui utilise pour le model avec les masker, il faut modifier le code en-dessous pour aller chercher un autre x_correl.

# %%
from nilearn.maskers import NiftiMasker
masker = NiftiMasker("/data/brambati/local/Core/fsl/6.0.4/data/standard/MNI152_T1_2mm_brain_mask.nii.gz") #si masker niftimasker MNI = devient tout les voxels

img_tpl = "/data/brambati/dataset/HCP/derivatives/seed-to-voxel-nilearn/results/sub-{0}/sub-{0}_voxelcorrelations.nii.gz"  # à changer

x_correl = []
nb_subjects = 200
subject_label = df["subject_label"][:nb_subjects]

for sub in tqdm(subject_label):
    img_path = str(Path(img_tpl.format(sub)))  # format = remplace entre accolades par # sujet
    x_correl.append(img4d2vector(img_path, masker))

x_correl = np.array(x_correl)
x_correl.shape  # autant de lignes que de sujets, autant de colones (nb region atlas x 8 (seeds))
# Out:
# 100%|██████████| 200/200 [02:15<00:00,  1.47it/s]
# (200, 1827864)

# %%
y_sex.shape
# Out:
# (1797,)

# %%
# code comes from : https://scikit-learn.org/stable/auto_examples/compose/plot_digits_pipe.html#sphx-glr-auto-examples-compose-plot-digits-pipe-py

# Code source: Gaël Varoquaux
# Modified for documentation by Jaques Grobler
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

# Define a pipeline to search for the best combination of PCA truncation
# and classifier regularization.
pca = PCA()
# Define a Standard Scaler to normalize inputs
scaler = StandardScaler()

# set the tolerance to a large value to make the example faster
svc = LinearSVC()
pipe = Pipeline(steps=[("scaler", scaler), ("pca", pca), ("prediction", svc)])

# max_feature = int(0.9*len(x_correl))
# n_components_range = range(0, max_feature, 10) # A range of different values for n_components

# Parameters of pipelines can be set using '__' separated parameter names:
param_grid = {
    "pca__n_components": [100, 200, 300, 400, 500],
    "prediction__C": np.logspace(-4, 4, 4),
}
search = GridSearchCV(pipe, param_grid, n_jobs=2)
search.fit(x_correl, y_sex)
print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)

# Plot the PCA spectrum
pca.fit(x_correl)

fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True, figsize=(6, 6))
ax0.plot(
    np.arange(1, pca.n_components_ + 1), pca.explained_variance_ratio_, "+", linewidth=2
)
ax0.set_ylabel("PCA explained variance ratio")

ax0.axvline(
    search.best_estimator_.named_steps["pca"].n_components,
    linestyle=":",
    label="n_components chosen",
)
ax0.legend(prop=dict(size=12))

# For each number of components, find the best classifier results
results = pd.DataFrame(search.cv_results_)
components_col = "param_pca__n_components"
best_clfs = results.groupby(components_col).apply(
    lambda g: g.nlargest(1, "mean_test_score")
)

best_clfs.plot(
    x=components_col, y="mean_test_score", yerr="std_test_score", legend=False, ax=ax1
)
ax1.set_ylabel("Classification accuracy (val)")
ax1.set_xlabel("n_components")

plt.xlim(0, 500)

plt.tight_layout()
plt.show()
# Out:
# /data/brambati/local/venvs/lingualab_server/lib/python3.6/site-packages/sklearn/model_selection/_search.py:925: UserWarning: One or more of the test scores are non-finite: [0.775 0.765 0.765 0.775   nan   nan   nan   nan   nan   nan   nan   nan
#    nan   nan   nan   nan   nan   nan   nan   nan]
#   category=UserWarning
# Best parameter (CV score=0.775):
# {'pca__n_components': 100, 'prediction__C': 0.0001}

# %%
if best_ncomp == 0:
    model = LinearSVC(max_iter=2000)
else:
    model = Pipeline([
            ('feature_selection', PCA(best_ncomp)),
            ('prediction', LinearSVC(max_iter=2000))
                      ])

model.fit(X_train,y_train) #fit the model/ train the model
y_pred = model.predict(X_test)

#calculate the model accuracy
acc = model.score(X_test, y_test)

#compute the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = conf_matrix.ravel()
df = pd.DataFrame(data=[[tn, fp],[fn,tp]], index= ["True", "False"], columns = ["Positive", "Negative"])
print(df.head())

# print results
print('accuracy (r2) =', acc)

# coef= model.coef_[0]
# coef_reshape = np.reshape(coef, (8, 193369))
# coef_reshape
# Out:
#        Positive  Negative
# True         16         3
# False         4        17
# accuracy (r2) = 0.825
